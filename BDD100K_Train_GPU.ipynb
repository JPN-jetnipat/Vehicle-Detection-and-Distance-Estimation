# %% [markdown]
# # Train YOLOv5 on BDD100K (GPU)
# This notebook assumes your GPU is available and that you are using the `.venv` kernel.

# %%
import os, sys

project = os.path.expanduser("~/Vehicle-Detection-and-Distance-Estimation/yolov5")
os.chdir(project)

print("Working directory:", os.getcwd())
print("Python:", sys.executable)
# Out:
# Working directory: /home/st6622780318/Vehicle-Detection-and-Distance-Estimation/yolov5
# Python: /home/st6622780318/Vehicle-Detection-and-Distance-Estimation/.venv/bin/python

# %%
import torch

print("=" * 50)
print("PyTorch Version :", torch.__version__)
print("CUDA Version    :", torch.version.cuda)
print("CUDA Available  :", torch.cuda.is_available())
print("GPU Count       :", torch.cuda.device_count())

if torch.cuda.is_available():
    print("GPU Name        :", torch.cuda.get_device_name(0))

    x = torch.rand(1000, 1000).cuda()
    y = torch.rand(1000, 1000).cuda()
    z = torch.matmul(x, y)

    print("\n✅ GPU is working correctly!")
    print("Tensor Device   :", z.device)
else:
    print("\n❌ GPU is NOT available.")
# Out:
# ...
# PyTorch Version : 2.5.1+cu121
# CUDA Version    : 12.1
# CUDA Available  : False
# GPU Count       : 0
#
# ❌ GPU is NOT available.

# %%
import torch

print("Torch:", torch.__version__)
print("CUDA version:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())
print("GPU count:", torch.cuda.device_count())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    raise RuntimeError("CUDA is not available. Check GPU/driver before training.")
# Out:
# Torch: 2.5.1+cu121
# CUDA version: 12.1
# CUDA available: False
# GPU count: 0
# /home/st6622780318/Vehicle-Detection-and-Distance-Estimation/.venv/lib/python3.10/site-packages/torch/cuda/__init__.py:716: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 11
#       9     print("GPU:", torch.cuda.get_device_name(0))
#      10 else:
# ---> 11     raise RuntimeError("CUDA is not available. Check GPU/driver before training.")
#
# RuntimeError: CUDA is not available. Check GPU/driver before training.

# %%
import sys

# !{sys.executable} train.py \
    --img 640 \
    --batch 8 \
    --epochs 100 \
    --data ../dataset/dataset/bdd100k_vehicle.yaml \
    --weights yolov5s.pt \
    --workers 2 \
    --device 0 \
    --name bdd100k_vehicle_100e_bs8_gpu
# Out:
# train: weights=yolov5s.pt, cfg=, data=../dataset/dataset/bdd100k_vehicle.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs/train, name=bdd100k_vehicle_100e_bs8_gpu, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# Traceback (most recent call last):
#   File "/home/st6622780318/Vehicle-Detection-and-Distance-Estimation/yolov5/train.py", line 1014, in <module>
# ...

# %%
import sys

# !{sys.executable} val.py \
    --weights runs/train/bdd100k_vehicle_100e_bs8_gpu/weights/best.pt \
    --data ../dataset/dataset/bdd100k_vehicle.yaml \
    --img 640 \
    --batch 8 \
    --device 0

# %%
import sys

# !{sys.executable} detect.py \
    --weights runs/train/bdd100k_vehicle_100e_bs8_gpu/weights/best.pt \
    --source ../dataset/dataset/raw/BDD100K/bdd100k/bdd100k/images/100k/val \
    --img 640 \
    --device 0

# %%
import sys

# !{sys.executable} train.py \
    --img 640 \
    --batch 8 \
    --epochs 1 \
    --data ../dataset/dataset/bdd100k_vehicle.yaml \
    --weights yolov5s.pt \
    --workers 2 \
    --name gpu_test
# Out:
# train: weights=yolov5s.pt, cfg=, data=../dataset/dataset/bdd100k_vehicle.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=1, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs/train, name=gpu_test, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2026-6-28 Python-3.10.12 torch-2.5.1+cu121 CPU
#
# ...
